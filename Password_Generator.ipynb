# %%
import random
import string

def generate_password(length, use_special_chars, use_numbers):
    characters = string.ascii_letters
    if use_special_chars:
        characters += string.punctuation
    if use_numbers:
        characters += string.digits

    password = ''.join(random.choice(characters) for _ in range(length))
    return password

def generate_multiple_passwords(num_passwords, min_length, max_length, use_special_chars, use_numbers):
    passwords = []
    for _ in range(num_passwords):
        length = random.randint(min_length, max_length)
        password = generate_password(length, use_special_chars, use_numbers)
        passwords.append(password)
    return passwords

def main():
    print("Password Generator")
    num_passwords = int(input("Enter the number of passwords to generate: "))
    min_length = int(input("Enter the minimum password length: "))
    max_length = int(input("Enter the maximum password length: "))
    use_special_chars = input("Include special characters (yes/no): ").lower() == "yes"
    use_numbers = input("Include numbers (yes/no): ").lower() == "yes"

    passwords = generate_multiple_passwords(num_passwords, min_length, max_length, use_special_chars, use_numbers)

    print("\nGenerated Passwords:")
    for i, password in enumerate(passwords, 1):
        print(f"Password {i}: {password}")

if __name__ == "__main__":
    main()
# Out:
# Password Generator
# Enter the number of passwords to generate: 30
# Enter the minimum password length: 20
# Enter the maximum password length: 25
# Include special characters (yes/no): no
# Include numbers (yes/no): yes
#
# Generated Passwords:
# Password 1: IJrlIoUObZSiBaF9KM83ja
# Password 2: IO6dqcvpIyugGssthgTmROvAY
# Password 3: Xdc0BxUb1sqmVmkU4Wwk
# Password 4: Rn1d7clIjIttHiRWlLLQrRGc
# Password 5: 7k86zgH6j1sT6HnCq9y7l
# Password 6: xFYL9xnPXLKnrgY6QLJ7K7SY
# Password 7: by8xpsIzandd98nC7J7XjMiLr
# Password 8: Iv196K52duswvHLXYTuO5qut
# Password 9: SX5GzqLVwEIScr4J2dJSl
# Password 10: 1rZYMBILRlRdlZJegDWvrD
# Password 11: tfeXP4VXKKJ1gW5fsWiCzmG
# Password 12: 2nIe5OpPdufvcoW3SgnNf
# Password 13: zDGx8Z2OPAZLi2nCkqiZm6I
# Password 14: YCURBLAhY159Ap2Acaqi5
# Password 15: bq2U8dfln6Fd6O3BG9dlvQzTP
# Password 16: vbxlbGDONaROJHsDmkR9g
# Password 17: GqXHcuMD0ofsWGLiKiWsLasMa
# Password 18: BqgdqkHrghnfDu6ISSpC3
# Password 19: 9RKMVzNuFBqaWslxFTWHO
# Password 20: RdsO36P9abbiX5gMrjwAy
# Password 21: 4AjmeFyzHqm9IwNORayy2ct
# Password 22: G0NeHl1V6tb3Wp3oKjegIx1d
# Password 23: Zomot6yXoRk31qcsJomsRTEaN
# Password 24: QF5vZuijoIqnrY6q2FF8
# Password 25: 1Mm3QiE0LeUsdZ5VT4bz5
# Password 26: xuMwErhJs7YIJXl6DKuG
# Password 27: Ev5bJN37qoNCRXMLC1TZuJk0
# Password 28: FVpdcBDuHnbKcJmmmzD9cWJXc
# Password 29: uxyrvXR0SezcBhtIrGbm2
# Password 30: 079mAiSNojgmxGAmQNBpG
